# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import sklearn
import random
from sklearn.utils import shuffle
import warnings
warnings.filterwarnings('ignore')

# %%
d=pd.read_csv('creditcard.csv')

# %%
sns.distplot(d['Amount'])
# Out:
# <Axes: xlabel='Amount', ylabel='Density'>

# %%
sns.distplot(d['Time'])
# Out:
# <Axes: xlabel='Time', ylabel='Density'>

# %%
d.hist(figsize=(20,20))
plt.show()

# %%
sns.jointplot(x= 'Time', y= 'Amount', data= d)

# %%
class0 = d[d['Class']==0]
len(class0)
# Out:
# 284315

# %%
class1 = d[d['Class']==1]
len(class1)
# Out:
# 492

# %%
temp = shuffle(class0)
d1 = temp.iloc[:2000,:]
d1
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 84725    60432.0  1.297915 -0.149956 -0.106596 -0.054844 -0.316204 -0.679624
# 259014  158920.0  1.874255 -0.654721 -0.501091  0.323216 -0.569018 -0.017319
# 82759    59540.0 -0.668078  1.265462  0.747935 -0.463522  0.617994  0.026326
# 282568  170994.0  1.990106  0.224995 -1.423252  1.492602  0.217817 -1.384993
# 30934    36144.0 -2.272379 -6.562943 -2.066841  0.972630 -2.585170  0.031164
# ...          ...       ...       ...       ...       ...       ...       ...
# 153543   99372.0 -0.189639  1.176888  0.320463 -0.451568  0.549708 -1.058645
# 276751  167277.0 -0.267428  1.271911 -0.026008  0.859516  0.004019 -0.096427
# 232671  147259.0  1.173591 -1.194198 -2.341772  1.645909 -0.026828 -1.375556
# 148526   90011.0  2.107225 -1.026486  0.536214 -0.545388 -1.654517 -0.328611
# 173734  121619.0  0.301112  0.833446 -0.524646  1.611325  0.444283 -0.828345
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 84725  -0.067162 -0.123338  0.441484  ... -0.036821 -0.195495 -0.159564
# 259014 -0.624131  0.065704  0.954979  ...  0.253062  0.815848  0.008031
# 82759   0.785586 -0.032540  0.021111  ... -0.412022 -0.844431 -0.167565
# 282568  0.657890 -0.445886  0.176976  ...  0.079750  0.445536  0.045205
# 30934   2.117325 -0.613720 -0.888325  ...  1.316870 -0.444548 -1.794429
# ...          ...       ...       ...  ...       ...       ...       ...
# 153543  0.939396 -0.312943  1.331278  ... -0.437960 -0.734432  0.073738
# 276751  0.182011  0.390004 -0.792284  ... -0.115704 -0.225521  0.096702
# 232671  1.349462 -0.581750  0.001236  ...  0.386920  0.112327 -0.404459
# 148526 -1.659919 -0.073856  1.753539  ...  0.290757  1.238152  0.186301
# 173734  0.904254 -0.533959  0.240264  ...  0.141394  1.037714  0.006824
#
#              V24       V25       V26       V27       V28   Amount  Class
# 84725  -0.412278  0.436063  1.124389 -0.100153 -0.005541    32.55      0
# 259014 -0.415777 -0.199909  0.616366 -0.035826 -0.053399    65.99      0
# 82759  -0.908925  0.030272  0.110376  0.296788 -0.033619    14.99      0
# 282568  0.405304  0.400264 -0.515505 -0.015216 -0.057039    13.50      0
# 30934   0.205624 -0.000245 -0.234830 -0.354241  0.328413  1902.00      0
# ...          ...       ...       ...       ...       ...      ...    ...
# 153543 -0.076176 -0.429056  0.105929  0.332569  0.153958     3.58      0
# 276751 -0.368210 -1.028856  0.563926  0.183801  0.187529     3.56      0
# 232671  0.032390  0.255718 -0.531760 -0.128560  0.014477   468.07      0
# 148526  0.026931 -0.404199 -0.135399  0.035991 -0.034239    15.99      0
# 173734  0.318497 -1.473396  0.847114 -0.262094 -0.140896    29.56      0
#
# [2000 rows x 31 columns]

# %%
frames = [d1, class1]
df_temp = pd.concat(frames)
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2492 entries, 84725 to 281674
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    2492 non-null   float64
#  1   V1      2492 non-null   float64
#  2   V2      2492 non-null   float64
#  3   V3      2492 non-null   float64
#  4   V4      2492 non-null   float64
#  5   V5      2492 non-null   float64
#  6   V6      2492 non-null   float64
#  7   V7      2492 non-null   float64
#  8   V8      2492 non-null   float64
#  9   V9      2492 non-null   float64
#  10  V10     2492 non-null   float64
#  11  V11     2492 non-null   float64
#  12  V12     2492 non-null   float64
#  13  V13     2492 non-null   float64
#  14  V14     2492 non-null   float64
#  15  V15     2492 non-null   float64
#  16  V16     2492 non-null   float64
#  17  V17     2492 non-null   float64
#  18  V18     2492 non-null   float64
#  19  V19     2492 non-null   float64
#  20  V20     2492 non-null   float64
#  21  V21     2492 non-null   float64
#  22  V22     2492 non-null   float64
#  23  V23     2492 non-null   float64
#  24  V24     2492 non-null   float64
#  25  V25     2492 non-null   float64
#  26  V26     2492 non-null   float64
#  27  V27     2492 non-null   float64
#  28  V28     2492 non-null   float64
#  29  Amount  2492 non-null   float64
#  30  Class   2492 non-null   int64
# dtypes: float64(30), int64(1)
# memory usage: 623.0 KB

# %%
df= shuffle(df_temp)
df.to_csv('creditcardsampling.csv')

# %%
X=df.iloc[ : ,:-1]
Y=df.iloc[: , -1]
X=pd.DataFrame(X)
Y=pd.DataFrame(Y)

# %%
names=['Time','V1','V2','V3','V4','V5','V6','V7','V8','V9','V10','V11','V12','V13','V14','V15','V16','V17','V18','V19','V20','V21','V22','V23','V24','V25','V26','V27','V28','Amount','Class']
data=pd.concat([X,Y],axis=1)
d=data.values
data=pd.DataFrame(d,columns=names)
data.describe()
# Out:
#                 Time           V1           V2           V3           V4  \
# count    2492.000000  2492.000000  2492.000000  2492.000000  2492.000000
# mean    93374.987961    -0.958554     0.698754    -1.364239     0.937589
# std     48005.054783     4.128240     3.210971     4.415968     2.554372
# min       154.000000   -56.407510   -72.715728   -31.103685    -4.283315
# 25%     51578.500000    -1.390624    -0.444329    -1.698585    -0.617968
# 50%     85305.000000    -0.301521     0.296059    -0.179578     0.362655
# 75%    139103.250000     1.221809     1.203297     0.798239     1.507387
# max    172712.000000     2.382503    22.057729     3.796873    16.491217
#
#                 V5           V6           V7           V8           V9  ...  \
# count  2492.000000  2492.000000  2492.000000  2492.000000  2492.000000  ...
# mean     -0.625919    -0.303580    -1.082988     0.094999    -0.525050  ...
# std       3.044758     1.623490     4.066261     3.204050     1.777675  ...
# min     -22.105532   -26.160506   -43.557242   -41.044261   -13.434066  ...
# 25%      -0.993603    -0.979028    -0.934861    -0.205889    -1.070513  ...
# 50%      -0.174237    -0.376203    -0.110199     0.047656    -0.230542  ...
# 75%       0.549898     0.269532     0.516494     0.438429     0.445031  ...
# max      34.801666     8.060516    21.246173    20.007208     7.689935  ...
#
#                V21          V22          V23          V24          V25  \
# count  2492.000000  2492.000000  2492.000000  2492.000000  2492.000000
# mean      0.133729     0.015846     0.018927    -0.011606     0.012446
# std       1.858372     0.924667     1.000312     0.577070     0.606927
# min     -22.797604    -8.887017   -19.254328    -2.539117    -4.781606
# 25%      -0.211396    -0.520546    -0.188094    -0.364637    -0.335955
# 50%       0.014905     0.025038    -0.015146     0.029469     0.030645
# 75%       0.300270     0.550351     0.172201     0.400984     0.370187
# max      27.202839     8.361985    22.083545     3.450094     6.070850
#
#                V26          V27          V28       Amount        Class
# count  2492.000000  2492.000000  2492.000000  2492.000000  2492.000000
# mean      0.016426     0.027770     0.036893    94.300903     0.197432
# std       0.490683     0.728544     0.763081   245.257942     0.398141
# min      -1.276233    -8.358317    -4.398798     0.000000     0.000000
# 25%      -0.305720    -0.067587    -0.050561     4.397500     0.000000
# 50%      -0.045917     0.015840     0.018479    21.565000     0.000000
# 75%       0.295405     0.186684     0.124418    87.270000     0.000000
# max       3.033586     6.578849    33.847808  6950.510000     1.000000
#
# [8 rows x 31 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2492 entries, 0 to 2491
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    2492 non-null   float64
#  1   V1      2492 non-null   float64
#  2   V2      2492 non-null   float64
#  3   V3      2492 non-null   float64
#  4   V4      2492 non-null   float64
#  5   V5      2492 non-null   float64
#  6   V6      2492 non-null   float64
#  7   V7      2492 non-null   float64
#  8   V8      2492 non-null   float64
#  9   V9      2492 non-null   float64
#  10  V10     2492 non-null   float64
#  11  V11     2492 non-null   float64
#  12  V12     2492 non-null   float64
#  13  V13     2492 non-null   float64
#  14  V14     2492 non-null   float64
#  15  V15     2492 non-null   float64
#  16  V16     2492 non-null   float64
#  17  V17     2492 non-null   float64
#  18  V18     2492 non-null   float64
#  19  V19     2492 non-null   float64
#  20  V20     2492 non-null   float64
#  21  V21     2492 non-null   float64
#  22  V22     2492 non-null   float64
#  23  V23     2492 non-null   float64
#  24  V24     2492 non-null   float64
#  25  V25     2492 non-null   float64
#  26  V26     2492 non-null   float64
#  27  V27     2492 non-null   float64
#  28  V28     2492 non-null   float64
#  29  Amount  2492 non-null   float64
#  30  Class   2492 non-null   float64
# dtypes: float64(31)
# memory usage: 603.7 KB

# %%
plt.figure(figsize=(12,10))
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
import math
import sklearn.preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score , classification_report, confusion_matrix, precision_recall_curve, f1_score, auc

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop('Class', axis=1), data['Class'], test_size=0.3, random_state=42)

# %% [markdown]
# # Feature Scaling

# %%
cols= ['V22', 'V24', 'V25', 'V26', 'V27', 'V28']
scaler = StandardScaler()
frames= ['Time', 'Amount']
x= data[frames]
d_temp = data.drop(frames, axis=1)
temp_col=scaler.fit_transform(x)
scaled_col = pd.DataFrame(temp_col, columns=frames)

# %%
scaled_col.head()
# Out:
#        Time    Amount
# 0 -0.862832 -0.150488
# 1  1.382465 -0.262229
# 2 -1.215678 -0.364673
# 3  1.395800 -0.380537
# 4  0.349034 -0.346402

# %%
d_scaled = pd.concat([scaled_col, d_temp], axis =1)
d_scaled.head()
# Out:
#        Time    Amount        V1        V2        V3        V4        V5  \
# 0 -0.862832 -0.150488  1.300660 -0.413234  0.178811 -0.464366 -1.015751
# 1  1.382465 -0.262229  0.138963  0.615447 -0.267482 -0.155520  0.735396
# 2 -1.215678 -0.364673 -0.652050  1.420041  1.405485  1.302044  0.724486
# 3  1.395800 -0.380537  2.048450 -0.106175 -1.205632  0.207864  0.108041
# 4  0.349034 -0.346402 -0.372833  0.054362  1.463301 -2.094535 -0.190216
#
#          V6        V7        V8  ...       V20       V21       V22       V23  \
# 0 -1.124867 -0.528333 -0.199170  ...  0.213983  0.076908  0.046900 -0.043089
# 1 -0.272549  0.992758 -0.160078  ... -0.466465 -0.119489  0.085923  0.014287
# 2 -0.847391  1.347294 -0.135899  ... -0.263188  0.049107 -0.032539 -0.331124
# 3 -0.665326  0.074686 -0.164677  ... -0.200112 -0.263302 -0.655196  0.279851
# 4 -0.130664 -0.299369  0.046125  ...  0.152843  0.313703  1.275549 -0.253670
#
#         V24       V25       V26       V27       V28  Class
# 0  0.317408  0.351508 -0.288259  0.021126  0.054196    0.0
# 1  0.640452 -0.599183 -0.643941  0.233394  0.222534    0.0
# 2  0.346952  0.415960 -0.086363  0.004865  0.082402    0.0
# 3 -0.405649 -0.274973  0.202632 -0.074684 -0.074136    0.0
# 4  0.660718 -0.108746 -0.162742  0.372940  0.223648    0.0
#
# [5 rows x 31 columns]

# %%
y = data['Class']

# %% [markdown]
# # Dimensionality Reduction

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=7)
X_temp_reduced = pca.fit_transform(d_scaled)
pca.explained_variance_ratio_
# Out:
# array([0.6151987 , 0.08201049, 0.06220401, 0.04859402, 0.03135141,
#        0.02625137, 0.01695939])

# %%
pca.explained_variance_
# Out:
# array([106.69966777,  14.22384649,  10.7886235 ,   8.42811545,
#          5.4375692 ,   4.5530212 ,   2.94142591])

# %%
names=['Time','Amount','Transaction Method','Transaction Id','Location','Type of Card','Bank']
X_reduced= pd.DataFrame(X_temp_reduced,columns=names)
X_reduced.head()
# Out:
#        Time    Amount  Transaction Method  Transaction Id  Location  \
# 0 -3.765760 -0.209118           -0.181223       -0.487130  0.397564
# 1 -3.863916  0.089910           -0.028850       -0.457183  0.059336
# 2 -3.768089  0.042042           -0.137355       -0.447493 -0.121231
# 3 -4.018929 -0.080306           -0.100598       -0.823647  0.036740
# 4 -3.976962  0.330591            0.207656       -0.417774 -1.220359
#
#    Type of Card      Bank
# 0     -0.268291  0.034615
# 1     -0.231495 -0.365601
# 2     -0.117870 -0.851908
# 3     -0.612590 -0.292431
# 4     -0.221150 -0.840860

# %%
Y=d_scaled['Class']

# %%
new_data=pd.concat([X_reduced,Y],axis=1)
new_data.head()
# Out:
#        Time    Amount  Transaction Method  Transaction Id  Location  \
# 0 -3.765760 -0.209118           -0.181223       -0.487130  0.397564
# 1 -3.863916  0.089910           -0.028850       -0.457183  0.059336
# 2 -3.768089  0.042042           -0.137355       -0.447493 -0.121231
# 3 -4.018929 -0.080306           -0.100598       -0.823647  0.036740
# 4 -3.976962  0.330591            0.207656       -0.417774 -1.220359
#
#    Type of Card      Bank  Class
# 0     -0.268291  0.034615    0.0
# 1     -0.231495 -0.365601    0.0
# 2     -0.117870 -0.851908    0.0
# 3     -0.612590 -0.292431    0.0
# 4     -0.221150 -0.840860    0.0

# %%
new_data.shape
# Out:
# (2492, 8)

# %%
new_data.to_csv('finaldata.csv')

# %%
X_train, X_test, y_train, y_test= train_test_split(X_reduced, d_scaled['Class'], test_size = 0.30, random_state = 42)
X_train.shape, X_test.shape
# Out:
# ((1744, 7), (748, 7))

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(X_train,y_train)
y_pred_lr=lr.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,y_pred_lr))
# Out:
# [[615   4]
#  [ 15 114]]

# %%
#Hyperparamter tuning 
from sklearn.model_selection import GridSearchCV
lr_model = LogisticRegression()
lr_params = {'penalty': ['l1', 'l2'],'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000]}
grid_lr= GridSearchCV(lr_model, param_grid = lr_params)
grid_lr.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
#                          'penalty': ['l1', 'l2']})

# %%
grid_lr.best_params_
# Out:
# {'C': 0.1, 'penalty': 'l2'}

# %%
y_pred_lr3=grid_lr.predict(X_test)
print(classification_report(y_test,y_pred_lr3))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99       619
#          1.0       0.97      0.88      0.93       129
#
#     accuracy                           0.98       748
#    macro avg       0.98      0.94      0.96       748
# weighted avg       0.98      0.98      0.98       748

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC
svc=SVC(kernel='rbf')
svc.fit(X_train,y_train)
y_pred_svc=svc.predict(X_test)

# %%
print(classification_report(y_test,y_pred_svc))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.98       619
#          1.0       0.99      0.84      0.91       129
#
#     accuracy                           0.97       748
#    macro avg       0.98      0.92      0.95       748
# weighted avg       0.97      0.97      0.97       748

# %%
print(confusion_matrix(y_test,y_pred_svc))
# Out:
# [[618   1]
#  [ 21 108]]

# %%
from sklearn.model_selection import GridSearchCV
parameters = [ {'C': [1, 10, 100, 1000], 'kernel': ['rbf'], 'gamma': [0.1, 1, 0.01, 0.0001 ,0.001]}]
grid_search = GridSearchCV(estimator = svc,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           n_jobs = -1)
grid_search = grid_search.fit(X_train, y_train)
best_accuracy = grid_search.best_score_
best_parameters = grid_search.best_params_
print("Best Accuracy: {:.2f} %".format(best_accuracy*100))
print("Best Parameters:", best_parameters)
# Out:
# Best Accuracy: 96.56 %
# Best Parameters: {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}

# %%
svc_param=SVC(kernel='rbf',gamma=0.01,C=100)
svc_param.fit(X_train,y_train)
y_pred_svc2=svc_param.predict(X_test)
print(classification_report(y_test,y_pred_svc2))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99       619
#          1.0       0.98      0.88      0.93       129
#
#     accuracy                           0.98       748
#    macro avg       0.98      0.94      0.96       748
# weighted avg       0.98      0.98      0.98       748

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(X_train,y_train)
y_pred_dtree=dtree.predict(X_test)
print(classification_report(y_test,y_pred_dtree))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.96      0.97       619
#          1.0       0.82      0.91      0.86       129
#
#     accuracy                           0.95       748
#    macro avg       0.90      0.93      0.91       748
# weighted avg       0.95      0.95      0.95       748

# %%
print(confusion_matrix(y_test,y_pred_dtree))
# Out:
# [[593  26]
#  [ 12 117]]

# %%
d_tree_param=DecisionTreeClassifier()
tree_parameters={'criterion':['gini','entropy'],'max_depth':list(range(2,4,1)),
                 'min_samples_leaf':list(range(5,7,1))}
grid_tree=GridSearchCV(d_tree_param,tree_parameters)
grid_tree.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'], 'max_depth': [2, 3],
#                          'min_samples_leaf': [5, 6]})

# %%
y_pred_dtree2=grid_tree.predict(X_test)

# %%
print(classification_report(y_test,y_pred_dtree2))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98       619
#          1.0       0.97      0.86      0.91       129
#
#     accuracy                           0.97       748
#    macro avg       0.97      0.93      0.95       748
# weighted avg       0.97      0.97      0.97       748

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
randomforest=RandomForestClassifier(n_estimators=5)
randomforest.fit(X_train,y_train)
y_pred_rf=randomforest.predict(X_test)
print(confusion_matrix(y_test,y_pred_rf))
# Out:
# [[608  11]
#  [ 13 116]]

# %%
print(classification_report(y_test,y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98       619
#          1.0       0.91      0.90      0.91       129
#
#     accuracy                           0.97       748
#    macro avg       0.95      0.94      0.94       748
# weighted avg       0.97      0.97      0.97       748

# %% [markdown]
# # K Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train)
y_pred_knn=knn.predict(X_test)

# %%
print(classification_report(y_test,y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.98       619
#          1.0       0.98      0.86      0.92       129
#
#     accuracy                           0.97       748
#    macro avg       0.98      0.93      0.95       748
# weighted avg       0.97      0.97      0.97       748

# %%
print(confusion_matrix(y_test,y_pred_knn))
# Out:
# [[617   2]
#  [ 18 111]]

# %%
knn_param=KNeighborsClassifier()
knn_params={"n_neighbors": list(range(2,5,1)), 'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']}
grid_knn=GridSearchCV(knn_param,param_grid=knn_params)
grid_knn.fit(X_train,y_train)
grid_knn.best_params_
# Out:
# {'algorithm': 'auto', 'n_neighbors': 4}

# %%
knn = KNeighborsClassifier(n_neighbors=2)

# %%
knn.fit(X_train,y_train)
pred_knn2 = knn.predict(X_test)

# %%
print('WITH K=3')
print('\n')
print(confusion_matrix(y_test,pred_knn2))
print('\n')
print(classification_report(y_test,pred_knn2))
# Out:
# WITH K=3
#
#
# [[618   1]
#  [ 17 112]]
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.99       619
#          1.0       0.99      0.87      0.93       129
#
#     accuracy                           0.98       748
#    macro avg       0.98      0.93      0.96       748
# weighted avg       0.98      0.98      0.98       748
